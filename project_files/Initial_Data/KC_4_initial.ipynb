# %%
# import necessary libraries and dependencies

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

# %%
# Read csv kcwt
kc_csv = Path('./KCWT_initial.csv')

# %%
# Read into pd dataframe
kc_df = pd.read_csv(kc_csv)
kc_df.head()
# Out:
#    Unnamed: 0  KC_score  KC_pct_legion KC_adm  KC_score.1  KC_pct_legion.1  \
# 0           0       1.0            NaN    NaN         2.0              NaN
# 1           1       NaN            NaN    NaN         NaN              NaN
# 2           2       NaN            NaN    NaN         NaN              NaN
# 3           3       NaN            NaN    NaN         NaN              NaN
# 4           4       NaN            NaN    NaN         NaN              NaN
#
#   KC_adm.1  KC_score.2  KC_pct_legion.2  KC_adm.2  KC_score.3  \
# 0      NaN         3.0              NaN       NaN         4.0
# 1      NaN         NaN              NaN       NaN         NaN
# 2      NaN         NaN              NaN       NaN         NaN
# 3      NaN         NaN              NaN       NaN         NaN
# 4      NaN         NaN              NaN       NaN         NaN
#
#    KC_pct_legion.3 KC_adm.3
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN

# %%
# Replace ADM score with 1
kc_df.loc[:, ['KC_adm', 'KC_adm.1', 'KC_adm.2', 'KC_adm.3']] = kc_df.loc[:, ['KC_adm', 'KC_adm.1', 'KC_adm.2', 'KC_adm.3']].replace(['A'], 1).fillna(0)
kc_df
# Out:
#     Unnamed: 0  KC_score  KC_pct_legion  KC_adm  KC_score.1  KC_pct_legion.1  \
# 0            0       1.0            NaN     0.0         2.0              NaN
# 1            1       NaN            NaN     0.0         NaN              NaN
# 2            2       NaN            NaN     0.0         NaN              NaN
# 3            3       NaN            NaN     0.0         NaN              NaN
# 4            4       NaN            NaN     0.0         NaN              NaN
# 5            5       0.0            NaN     0.0         0.0              NaN
# 6            6       1.0            NaN     1.0         0.0              NaN
# 7            7       2.0            NaN     1.0         0.0              NaN
# 8            8       0.0            NaN     0.0         0.0              NaN
# 9            9       0.0            NaN     0.0         2.0              NaN
# 10          10       0.0            NaN     0.0         2.0              NaN
# 11          11       0.0            NaN     0.0         0.0              NaN
# 12          12       0.0            NaN     0.0         1.0              NaN
# 13          13       1.0            NaN     0.0         0.0              NaN
# 14          14       1.0            NaN     1.0         1.0              NaN
# 15          15       0.0            NaN     0.0         2.0              NaN
# 16          16       0.0            NaN     0.0         0.0              NaN
# 17          17       0.0            NaN     0.0         0.0              NaN
# 18          18       0.0            NaN     0.0         1.0              NaN
# 19          19       1.0            NaN     0.0         1.0              NaN
# 20          20       0.0            NaN     0.0         0.0              NaN
# 21          21       2.0            NaN     0.0         1.0              NaN
# 22          22       0.0            NaN     0.0         0.0              NaN
# 23          23       0.0            NaN     0.0         1.0              NaN
# 24          24       0.0            NaN     0.0         1.0              NaN
# 25          25       2.0            NaN     0.0         0.0              NaN
# 26          26       1.0            NaN     0.0         0.0              NaN
# 27          27       0.0            NaN     0.0         0.0              NaN
# 28          28       NaN            NaN     0.0         1.0              NaN
# 29          29       NaN            NaN     0.0         0.0              NaN
# 30          30       NaN            NaN     0.0         1.0              NaN
# 31          31       NaN            NaN     0.0         0.0              NaN
# 32          32       NaN            NaN     0.0         0.0              NaN
# 33          33       NaN            NaN     0.0         1.0              NaN
# 34          34       NaN            NaN     0.0         NaN              NaN
# 35          35       NaN            NaN     0.0         NaN              NaN
# 36          36       NaN            NaN     0.0         NaN              NaN
# 37          37       NaN            NaN     0.0         NaN              NaN
#
#     KC_adm.1  KC_score.2  KC_pct_legion.2  KC_adm.2  KC_score.3  \
# 0        0.0         3.0              NaN       0.0         4.0
# 1        0.0         NaN              NaN       0.0         NaN
# 2        0.0         NaN              NaN       0.0         NaN
# 3        0.0         NaN              NaN       0.0         NaN
# 4        0.0         NaN              NaN       0.0         NaN
# 5        0.0         0.0              NaN       0.0         2.0
# 6        0.0         1.0              NaN       0.0         2.0
# 7        0.0         2.0              NaN       0.0         1.0
# 8        0.0         1.0              NaN       0.0         1.0
# 9        0.0         0.0              NaN       0.0         3.0
# 10       0.0         0.0              NaN       0.0         0.0
# 11       0.0         1.0              NaN       0.0         1.0
# 12       0.0         2.0              NaN       0.0         0.0
# 13       0.0         0.0              NaN       0.0         0.0
# 14       0.0         2.0              NaN       0.0         1.0
# 15       0.0         0.0              NaN       0.0         3.0
# 16       0.0         0.0              NaN       0.0         0.0
# 17       0.0         0.0              NaN       0.0         1.0
# 18       0.0         1.0              NaN       0.0         0.0
# 19       1.0         0.0              NaN       0.0         4.0
# 20       0.0         0.0              NaN       0.0         1.0
# 21       0.0         1.0              NaN       0.0         2.0
# 22       0.0         0.0              NaN       0.0         2.0
# 23       0.0         1.0              NaN       0.0         0.0
# 24       0.0         0.0              NaN       0.0         3.0
# 25       1.0         2.0              NaN       0.0         1.0
# 26       0.0         1.0              NaN       0.0         3.0
# 27       0.0         1.0              NaN       0.0         0.0
# 28       0.0         1.0              NaN       0.0         1.0
# 29       0.0         1.0              NaN       0.0         0.0
# 30       1.0         1.0             25.0       0.0         0.0
# 31       0.0         NaN              NaN       0.0         0.0
# 32       0.0         NaN              NaN       0.0         NaN
# 33       0.0         NaN              NaN       0.0         NaN
# 34       0.0         NaN              NaN       0.0         NaN
# 35       0.0         NaN              NaN       0.0         NaN
# 36       0.0         NaN              NaN       0.0         NaN
# 37       0.0         NaN              NaN       0.0         NaN
#
#     KC_pct_legion.3  KC_adm.3
# 0               NaN       0.0
# 1               NaN       0.0
# 2               NaN       0.0
# 3               NaN       0.0
# 4               NaN       0.0
# 5               NaN       1.0
# 6               NaN       1.0
# 7               NaN       1.0
# 8               NaN       0.0
# 9               NaN       1.0
# 10              NaN       0.0
# 11              NaN       0.0
# 12              NaN       0.0
# 13              NaN       0.0
# 14              NaN       1.0
# 15              NaN       1.0
# 16              NaN       0.0
# 17              NaN       1.0
# 18              NaN       0.0
# 19              NaN       0.0
# 20              NaN       0.0
# 21              NaN       1.0
# 22              NaN       1.0
# 23              NaN       0.0
# 24              NaN       1.0
# 25              NaN       1.0
# 26              NaN       1.0
# 27              NaN       0.0
# 28              NaN       0.0
# 29              NaN       0.0
# 30              NaN       0.0
# 31              NaN       0.0
# 32              NaN       0.0
# 33              NaN       0.0
# 34              NaN       0.0
# 35              NaN       0.0
# 36              NaN       0.0
# 37              NaN       0.0

# %%
# insert new column into dataframe
kc_mouse_id_df = kc_df
kc_mouse_id_df.insert(1, 'id_1', 1)

# %%
# insert mouse ID 2
kc_mouse_id_df.insert(5, 'id_2', 2)
kc_mouse_id_df.head()
# Out:
#    Unnamed: 0  id_1  KC_score  KC_pct_legion  KC_adm  id_2  KC_score.1  \
# 0           0     1       1.0            NaN     0.0     2         2.0
# 1           1     1       NaN            NaN     0.0     2         NaN
# 2           2     1       NaN            NaN     0.0     2         NaN
# 3           3     1       NaN            NaN     0.0     2         NaN
# 4           4     1       NaN            NaN     0.0     2         NaN
#
#    KC_pct_legion.1  KC_adm.1  KC_score.2  KC_pct_legion.2  KC_adm.2  \
# 0              NaN       0.0         3.0              NaN       0.0
# 1              NaN       0.0         NaN              NaN       0.0
# 2              NaN       0.0         NaN              NaN       0.0
# 3              NaN       0.0         NaN              NaN       0.0
# 4              NaN       0.0         NaN              NaN       0.0
#
#    KC_score.3  KC_pct_legion.3  KC_adm.3
# 0         4.0              NaN       0.0
# 1         NaN              NaN       0.0
# 2         NaN              NaN       0.0
# 3         NaN              NaN       0.0
# 4         NaN              NaN       0.0

# %%
# insert mouse ID 3
kc_mouse_id_df.insert(9, 'id_3', 3)
kc_mouse_id_df.head()
# Out:
#    Unnamed: 0  id_1  KC_score  KC_pct_legion  KC_adm  id_2  KC_score.1  \
# 0           0     1       1.0            NaN     0.0     2         2.0
# 1           1     1       NaN            NaN     0.0     2         NaN
# 2           2     1       NaN            NaN     0.0     2         NaN
# 3           3     1       NaN            NaN     0.0     2         NaN
# 4           4     1       NaN            NaN     0.0     2         NaN
#
#    KC_pct_legion.1  KC_adm.1  id_3  KC_score.2  KC_pct_legion.2  KC_adm.2  \
# 0              NaN       0.0     3         3.0              NaN       0.0
# 1              NaN       0.0     3         NaN              NaN       0.0
# 2              NaN       0.0     3         NaN              NaN       0.0
# 3              NaN       0.0     3         NaN              NaN       0.0
# 4              NaN       0.0     3         NaN              NaN       0.0
#
#    KC_score.3  KC_pct_legion.3  KC_adm.3
# 0         4.0              NaN       0.0
# 1         NaN              NaN       0.0
# 2         NaN              NaN       0.0
# 3         NaN              NaN       0.0
# 4         NaN              NaN       0.0

# %%
# insert mouse ID 4
kc_mouse_id_df.insert(13, 'id_4', 4)
kc_mouse_id_df.head()
# Out:
#    Unnamed: 0  id_1  KC_score  KC_pct_legion  KC_adm  id_2  KC_score.1  \
# 0           0     1       1.0            NaN     0.0     2         2.0
# 1           1     1       NaN            NaN     0.0     2         NaN
# 2           2     1       NaN            NaN     0.0     2         NaN
# 3           3     1       NaN            NaN     0.0     2         NaN
# 4           4     1       NaN            NaN     0.0     2         NaN
#
#    KC_pct_legion.1  KC_adm.1  id_3  KC_score.2  KC_pct_legion.2  KC_adm.2  \
# 0              NaN       0.0     3         3.0              NaN       0.0
# 1              NaN       0.0     3         NaN              NaN       0.0
# 2              NaN       0.0     3         NaN              NaN       0.0
# 3              NaN       0.0     3         NaN              NaN       0.0
# 4              NaN       0.0     3         NaN              NaN       0.0
#
#    id_4  KC_score.3  KC_pct_legion.3  KC_adm.3
# 0     4         4.0              NaN       0.0
# 1     4         NaN              NaN       0.0
# 2     4         NaN              NaN       0.0
# 3     4         NaN              NaN       0.0
# 4     4         NaN              NaN       0.0

# %%
kc_mouse_id_df['id_1'] = 1 
kc_mouse_id_df['id_2'] = 2
kc_mouse_id_df['id_3'] = 3
kc_mouse_id_df['id_4'] = 4
kc_mouse_id_df.head()
# Out:
#    Unnamed: 0  id_1  KC_score  KC_pct_legion  KC_adm  id_2  KC_score.1  \
# 0           0     1       1.0            NaN     0.0     2         2.0
# 1           1     1       NaN            NaN     0.0     2         NaN
# 2           2     1       NaN            NaN     0.0     2         NaN
# 3           3     1       NaN            NaN     0.0     2         NaN
# 4           4     1       NaN            NaN     0.0     2         NaN
#
#    KC_pct_legion.1  KC_adm.1  id_3  KC_score.2  KC_pct_legion.2  KC_adm.2  \
# 0              NaN       0.0     3         3.0              NaN       0.0
# 1              NaN       0.0     3         NaN              NaN       0.0
# 2              NaN       0.0     3         NaN              NaN       0.0
# 3              NaN       0.0     3         NaN              NaN       0.0
# 4              NaN       0.0     3         NaN              NaN       0.0
#
#    id_4  KC_score.3  KC_pct_legion.3  KC_adm.3
# 0     4         4.0              NaN       0.0
# 1     4         NaN              NaN       0.0
# 2     4         NaN              NaN       0.0
# 3     4         NaN              NaN       0.0
# 4     4         NaN              NaN       0.0

# %%
kc_mouse_id_df.head()
# Out:
#    Unnamed: 0  id_1  KC_score  KC_pct_legion  KC_adm  id_2  KC_score.1  \
# 0           0     1       1.0            NaN     0.0     2         2.0
# 1           1     1       NaN            NaN     0.0     2         NaN
# 2           2     1       NaN            NaN     0.0     2         NaN
# 3           3     1       NaN            NaN     0.0     2         NaN
# 4           4     1       NaN            NaN     0.0     2         NaN
#
#    KC_pct_legion.1  KC_adm.1  id_3  KC_score.2  KC_pct_legion.2  KC_adm.2  \
# 0              NaN       0.0     3         3.0              NaN       0.0
# 1              NaN       0.0     3         NaN              NaN       0.0
# 2              NaN       0.0     3         NaN              NaN       0.0
# 3              NaN       0.0     3         NaN              NaN       0.0
# 4              NaN       0.0     3         NaN              NaN       0.0
#
#    id_4  KC_score.3  KC_pct_legion.3  KC_adm.3
# 0     4         4.0              NaN       0.0
# 1     4         NaN              NaN       0.0
# 2     4         NaN              NaN       0.0
# 3     4         NaN              NaN       0.0
# 4     4         NaN              NaN       0.0

# %%
# use the scatterplot function to build the bubble map
# kc1
plot_1 = sns.scatterplot(data=kc_mouse_id_df, x="Unnamed: 0", y="id_1", 
                         size="KC_score", legend=False, sizes=(5, 200), 
                         hue='KC_adm')

# show the graph
plt.show(plot_1)

# %%
# create kc2
ax = sns.scatterplot(legend=False,
                     data=kc_mouse_id_df, x="Unnamed: 0", y="id_2", 
                     size="KC_score.1", sizes=(5, 200), 
                     hue='KC_adm.1')

# %%
# create kc3
plot_3 = sns.scatterplot(data=kc_mouse_id_df, x="Unnamed: 0", y="id_3", 
                         size="KC_score.2", legend=False, sizes=(5, 200), 
                         hue='KC_adm.2')

# %%
# create kc2
plot_4 = sns.scatterplot(data=kc_mouse_id_df, x="Unnamed: 0", y="id_4", 
                         size="KC_score.3", legend=False, sizes=(5, 200), 
                         hue='KC_adm.3')

# %%
# create overlays
plt.figure(figsize=(6,15))
plt.show()

# %%
# restructure data
kc_1_df = (kc_mouse_id_df.loc[:, ['Unnamed: 0', 'id_1', 'KC_score', 'KC_adm']].assign(group = 'id_1').set_axis(['field', 'id', 'score', 'adm', 'id_1'], axis=1))

kc_2_df = (kc_mouse_id_df.loc[:, ['Unnamed: 0', 'id_2', 'KC_score.1', 'KC_adm.1']].assign(group = 'id_2').set_axis(['field', 'id', 'score', 'adm', 'id_2',], axis=1))

kc_3_df = (kc_mouse_id_df.loc[:, ['Unnamed: 0', 'id_3', 'KC_score.2', 'KC_adm.2']].assign(group = 'id_3').set_axis(['field', 'id', 'score', 'adm', 'id_3'], axis=1))


kc_4_df = (kc_mouse_id_df.loc[:, ['Unnamed: 0', 'id_4', 'KC_score.3', 'KC_adm.3']].assign(group = 'id_4').set_axis(['field', 'id', 'score', 'adm', 'id_4'], axis=1))

# %%
# merge dataframes
merged_dataframe = pd.concat([kc_1_df, kc_2_df, kc_3_df, kc_4_df], ignore_index=True)

# %%
# plot merged df
# sns.set_style("whitegrid")
cmap = ['gray', 'blue',]
g = sns.relplot(data=merged_dataframe, 
            x='field', 
            y='id',
            hue='adm', 
            size='score',
            sizes=(15, 500),
            height=6,
            aspect=3,
            palette=cmap,
            )

# Change axis titles
g.set(title="4 KC MICE", xlabel='Fields', ylabel='Mouse')


# Save fig
plt.savefig('KC_grid_plot.pdf', dpi=300)

# %%
"""
https://stackoverflow.com/questions/64750489/how-to-overlay-two-seaborn-relplots
"""
# Out:
# '\nhttps://stackoverflow.com/questions/64750489/how-to-overlay-two-seaborn-relplots\n'

# %% [markdown]
# 7:40-9:00
#
# gray being 0,
#
# 1 = blue
#
# 2 = green
#
# 3 = pink
#
# 4 red because later you only have one dot, but larger legions,
#
#
# No grid line, very small dot for 0
#
# 704 and 671 no adm, might exclude, might not be any adm on the last two
#
# Color scale for pct legion 0, 25, 50, 75, 100 - show the size becaue at later time points there are many more large legions in the KCG mice, dont initiate as fast but need to be shown at the begnning.
# gray to red
# include adm in background with bigger circle, yellow circle or no circle, should be circumference of largest dot.
# adm on mice with one or two legions or on mice that is right next
# suggests mechanism for how disease develops
#
# score - size tells you how many lesions
#
# pct legion - the larger lesions would be more intense, becuase larger lesion, but fewer lesions.
# one large lesion would cover most of the field, want it to be the most intense color.

# %% [markdown]
# https://altair-viz.github.io/gallery/multifeature_scatter_plot.html

# %%
import altair as alt
from vega_datasets import data

# %%
alt.Chart(merged_dataframe).mark_circle().encode(
    alt.X('field', scale=alt.Scale(zero=False)),
    alt.Y('', scale=alt.Scale(zero=False, padding=1)),
    color='adm',
    size='score'
)

# %% [markdown]
# https://holoviews.org/gallery/demos/bokeh/scatter_economic.html
