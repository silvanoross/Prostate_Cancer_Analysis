# %%
# import necessary libraries and dependencies

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path

# %%
# Read csv kcwt
total_path = Path('../resources/P40-60_SR_PROCESS_READY.csv')

# %%
# Read into pd dataframe
total_df = pd.read_csv(total_path)
total_df.head()
# Out:
#    Field  KCG_LESION  KCG_ADM  KCG_LESION.1  KCG_ADM.1  KCG_LESION.2  \
# 0      0         0.0      NaN           1.0        NaN           2.0
# 1      1         NaN      NaN           NaN        NaN           NaN
# 2      2         NaN      NaN           NaN        NaN           NaN
# 3      3         NaN      NaN           NaN        NaN           NaN
# 4      4         NaN      NaN           NaN        NaN           NaN
#
#    KCG_ADM.2  KCG_LESION.3  KCG_ADM.3  KCG_LESION.4  ...  KC_LESION.7  \
# 0        NaN           3.0        NaN           4.0  ...          NaN
# 1        NaN           NaN        NaN           NaN  ...          NaN
# 2        NaN           NaN        NaN           NaN  ...          NaN
# 3        NaN           NaN        NaN           NaN  ...          NaN
# 4        NaN           NaN        NaN           NaN  ...          NaN
#
#    KC_ADM.7  KC_LESION.8  KC_ADM.8  KC_LESION.9  KC_ADM.9 KC_LESION.10  \
# ...

# %%
# Replace all As with 1s and all NaN with 
total_df = total_df.replace('A', 1)

# Review dataframe
total_df.head()
# Out:
#    Field  KCG_LESION  KCG_ADM  KCG_LESION.1  KCG_ADM.1  KCG_LESION.2  \
# 0      0         0.0      NaN           1.0        NaN           2.0
# 1      1         NaN      NaN           NaN        NaN           NaN
# 2      2         NaN      NaN           NaN        NaN           NaN
# 3      3         NaN      NaN           NaN        NaN           NaN
# 4      4         NaN      NaN           NaN        NaN           NaN
#
#    KCG_ADM.2  KCG_LESION.3  KCG_ADM.3  KCG_LESION.4  ...  KC_LESION.7  \
# 0        NaN           3.0        NaN           4.0  ...          NaN
# 1        NaN           NaN        NaN           NaN  ...          NaN
# 2        NaN           NaN        NaN           NaN  ...          NaN
# 3        NaN           NaN        NaN           NaN  ...          NaN
# 4        NaN           NaN        NaN           NaN  ...          NaN
#
#    KC_ADM.7  KC_LESION.8  KC_ADM.8  KC_LESION.9  KC_ADM.9  KC_LESION.10  \
# ...

# %%
# Slice KCG dataframe
KCG_df = total_df.iloc[:, 0:35]
KCG_df.head()
# Out:
#    Field  KCG_LESION  KCG_ADM  KCG_LESION.1  KCG_ADM.1  KCG_LESION.2  \
# 0      0         0.0      NaN           1.0        NaN           2.0
# 1      1         NaN      NaN           NaN        NaN           NaN
# 2      2         NaN      NaN           NaN        NaN           NaN
# 3      3         NaN      NaN           NaN        NaN           NaN
# 4      4         NaN      NaN           NaN        NaN           NaN
#
#    KCG_ADM.2  KCG_LESION.3  KCG_ADM.3  KCG_LESION.4  ...  KCG_LESION.12  \
# 0        NaN           3.0        NaN           4.0  ...            NaN
# 1        NaN           NaN        NaN           NaN  ...            NaN
# 2        NaN           NaN        NaN           NaN  ...            NaN
# 3        NaN           NaN        NaN           NaN  ...            NaN
# 4        NaN           NaN        NaN           NaN  ...            NaN
#
#    KCG_ADM.12  KCG_LESION.13  KCG_ADM.13  KCG_LESION.14  KCG_ADM.14  \
# ...

# %%
# Slice KC dataframe
KC_df = total_df.iloc[:, 35:]

# Add the Field attribute
KC_df['Field'] = total_df['Field']

# Preview DataFrame
KC_df.head()
# Out:
#    KC_LESION  KC_ADM  KC_LESION.1  KC_ADM.1  KC_LESION.2  KC_ADM.2  \
# 0        0.0     NaN          1.0       NaN          2.0       NaN
# 1        NaN     NaN          NaN       NaN          NaN       NaN
# 2        NaN     NaN          NaN       NaN          NaN       NaN
# 3        NaN     NaN          NaN       NaN          NaN       NaN
# 4        NaN     NaN          NaN       NaN          NaN       NaN
#
#    KC_LESION.3  KC_ADM.3  KC_LESION.4  KC_ADM.4  ...  KC_ADM.7  KC_LESION.8  \
# 0          3.0       NaN          4.0       NaN  ...       NaN          NaN
# 1          NaN       NaN          NaN       NaN  ...       NaN          NaN
# 2          NaN       NaN          NaN       NaN  ...       NaN          NaN
# 3          NaN       NaN          NaN       NaN  ...       NaN          NaN
# 4          NaN       NaN          NaN       NaN  ...       NaN          NaN
#
#    KC_ADM.8  KC_LESION.9  KC_ADM.9  KC_LESION.10  KC_ADM.10  KC_LESION.11  \
# ...

# %%
# Create the KCG groups 1-17
kcg_1_df = (KCG_df.loc[:, ['Field', 'KCG_LESION', 'KCG_ADM']].assign(group = 'id_1').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_1'], axis=1))
kcg_2_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.1', 'KCG_ADM.1']].assign(group = 'id_2').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_2'], axis=1))
kcg_3_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.2', 'KCG_ADM.2']].assign(group = 'id_3').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_3'], axis=1))
kcg_4_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.3', 'KCG_ADM.3']].assign(group = 'id_4').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_4'], axis=1))
kcg_5_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.4', 'KCG_ADM.4']].assign(group = 'id_5').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_5'], axis=1))
kcg_6_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.5', 'KCG_ADM.5']].assign(group = 'id_6').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_6'], axis=1))
kcg_7_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.6', 'KCG_ADM.6']].assign(group = 'id_7').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_7'], axis=1))
kcg_8_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.7', 'KCG_ADM.7']].assign(group = 'id_8').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_8'], axis=1))
kcg_9_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.8', 'KCG_ADM.8']].assign(group = 'id_9').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_9'], axis=1))
kcg_10_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.9', 'KCG_ADM.9']].assign(group = 'id_10').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_10'], axis=1))
kcg_11_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.10', 'KCG_ADM.10']].assign(group = 'id_11').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_11'], axis=1))
kcg_12_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.11', 'KCG_ADM.11']].assign(group = 'id_12').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_12'], axis=1))
kcg_13_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.12', 'KCG_ADM.12']].assign(group = 'id_13').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_13'], axis=1))
kcg_14_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.13', 'KCG_ADM.13']].assign(group = 'id_14').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_14'], axis=1))
kcg_15_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.14', 'KCG_ADM.14']].assign(group = 'id_15').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_15'], axis=1))
kcg_16_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.15', 'KCG_ADM.15']].assign(group = 'id_16').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_16'], axis=1))
kcg_17_df = (KCG_df.loc[:, ['Field', 'KCG_LESION.16', 'KCG_ADM.16']].assign(group = 'id_17').set_axis(['Field','KCG_LESION', 'KCG_ADM', 'id_17'], axis=1))

# %%
# Create the KC groups 1-12
kc_1_df = (KC_df.loc[:, ['Field', 'KC_LESION', 'KC_ADM']].assign(group = 'id_1').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_1'], axis=1))
kc_2_df = (KC_df.loc[:, ['Field', 'KC_LESION.1', 'KC_ADM.1']].assign(group = 'id_2').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_2'], axis=1))
kc_3_df = (KC_df.loc[:, ['Field', 'KC_LESION.2', 'KC_ADM.2']].assign(group = 'id_3').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_3'], axis=1))
kc_4_df = (KC_df.loc[:, ['Field', 'KC_LESION.3', 'KC_ADM.3']].assign(group = 'id_4').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_4'], axis=1))
kc_5_df = (KC_df.loc[:, ['Field', 'KC_LESION.4', 'KC_ADM.4']].assign(group = 'id_5').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_5'], axis=1))
kc_6_df = (KC_df.loc[:, ['Field', 'KC_LESION.5', 'KC_ADM.5']].assign(group = 'id_6').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_6'], axis=1))
kc_7_df = (KC_df.loc[:, ['Field', 'KC_LESION.6', 'KC_ADM.6']].assign(group = 'id_7').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_7'], axis=1))
kc_8_df = (KC_df.loc[:, ['Field', 'KC_LESION.7', 'KC_ADM.7']].assign(group = 'id_8').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_8'], axis=1))
kc_9_df = (KC_df.loc[:, ['Field', 'KC_LESION.8', 'KC_ADM.8']].assign(group = 'id_9').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_9'], axis=1))
kc_10_df = (KC_df.loc[:, ['Field', 'KC_LESION.9', 'KC_ADM.9']].assign(group = 'id_10').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_10'], axis=1))
kc_11_df = (KC_df.loc[:, ['Field', 'KC_LESION.10', 'KC_ADM.10']].assign(group = 'id_11').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_11'], axis=1))
kc_12_df = (KC_df.loc[:, ['Field', 'KC_LESION.11', 'KC_ADM.11']].assign(group = 'id_12').set_axis(['Field','KC_LESION', 'KC_ADM', 'id_12'], axis=1))

# %%
# Add the 'Mouse' column to KCG
kcg_1_df['mouse'] = '1'
kcg_2_df['mouse'] = '2'
kcg_3_df['mouse'] = '3'
kcg_4_df['mouse'] = '4'
kcg_5_df['mouse'] = '5'
kcg_6_df['mouse'] = '6'
kcg_7_df['mouse'] = '7'
kcg_8_df['mouse'] = '8'
kcg_9_df['mouse'] = '9'
kcg_10_df['mouse'] = '10'
kcg_11_df['mouse'] = '11'
kcg_12_df['mouse'] = '12'
kcg_13_df['mouse'] = '13'
kcg_14_df['mouse'] = '14'
kcg_15_df['mouse'] = '15'
kcg_16_df['mouse'] = '16'
kcg_17_df['mouse'] = '17'

# %%
# Add the mouse column to KC
kc_1_df['mouse'] = '1'
kc_2_df['mouse'] = '2'
kc_3_df['mouse'] = '3'
kc_4_df['mouse'] = '4'
kc_5_df['mouse'] = '5'
kc_6_df['mouse'] = '6'
kc_7_df['mouse'] = '7'
kc_8_df['mouse'] = '8'
kc_9_df['mouse'] = '9'
kc_10_df['mouse'] = '10'
kc_11_df['mouse'] = '11'
kc_12_df['mouse'] = '12'

# %%
# Review a couple
display(kc_1_df.head())
display(kc_12_df.head())
# Out:
#    Field  KC_LESION  KC_ADM  id_1 mouse
# 0      0        0.0     NaN  id_1     1
# 1      1        NaN     NaN  id_1     1
# 2      2        NaN     NaN  id_1     1
# 3      3        NaN     NaN  id_1     1
# 4      4        NaN     NaN  id_1     1
#    Field  KC_LESION  KC_ADM  id_12 mouse
# 0      0        NaN     NaN  id_12    12
# 1      1        NaN     NaN  id_12    12
# 2      2        NaN     NaN  id_12    12
# 3      3        NaN     NaN  id_12    12
# 4      4        NaN     NaN  id_12    12

# %%
# Turn Nan in ADM column to 0s in KCG
kcg_1_df['KCG_ADM'] = kcg_1_df['KCG_ADM'].fillna(0)
kcg_2_df['KCG_ADM'] = kcg_2_df['KCG_ADM'].fillna(0)
kcg_3_df['KCG_ADM'] = kcg_3_df['KCG_ADM'].fillna(0)
kcg_4_df['KCG_ADM'] = kcg_4_df['KCG_ADM'].fillna(0)
kcg_5_df['KCG_ADM'] = kcg_5_df['KCG_ADM'].fillna(0)
kcg_6_df['KCG_ADM'] = kcg_6_df['KCG_ADM'].fillna(0)
kcg_7_df['KCG_ADM'] = kcg_7_df['KCG_ADM'].fillna(0)
kcg_8_df['KCG_ADM'] = kcg_8_df['KCG_ADM'].fillna(0)
kcg_9_df['KCG_ADM'] = kcg_9_df['KCG_ADM'].fillna(0)
kcg_10_df['KCG_ADM'] = kcg_10_df['KCG_ADM'].fillna(0)
kcg_11_df['KCG_ADM'] = kcg_11_df['KCG_ADM'].fillna(0)
kcg_12_df['KCG_ADM'] = kcg_12_df['KCG_ADM'].fillna(0)
kcg_13_df['KCG_ADM'] = kcg_13_df['KCG_ADM'].fillna(0)
kcg_14_df['KCG_ADM'] = kcg_14_df['KCG_ADM'].fillna(0)
kcg_15_df['KCG_ADM'] = kcg_15_df['KCG_ADM'].fillna(0)
kcg_16_df['KCG_ADM'] = kcg_16_df['KCG_ADM'].fillna(0)
kcg_17_df['KCG_ADM'] = kcg_17_df['KCG_ADM'].fillna(0)

# %%
# Turn Nan in ADM column to 0s in KC
kc_1_df['KC_ADM'] = kc_1_df['KC_ADM'].fillna(0)
kc_2_df['KC_ADM'] = kc_2_df['KC_ADM'].fillna(0)
kc_3_df['KC_ADM'] = kc_3_df['KC_ADM'].fillna(0)
kc_4_df['KC_ADM'] = kc_4_df['KC_ADM'].fillna(0)
kc_5_df['KC_ADM'] = kc_5_df['KC_ADM'].fillna(0)
kc_6_df['KC_ADM'] = kc_6_df['KC_ADM'].fillna(0)
kc_7_df['KC_ADM'] = kc_7_df['KC_ADM'].fillna(0)
kc_8_df['KC_ADM'] = kc_8_df['KC_ADM'].fillna(0)
kc_9_df['KC_ADM'] = kc_9_df['KC_ADM'].fillna(0)
kc_10_df['KC_ADM'] = kc_10_df['KC_ADM'].fillna(0)
kc_11_df['KC_ADM'] = kc_11_df['KC_ADM'].fillna(0)
kc_12_df['KC_ADM'] = kc_12_df['KC_ADM'].fillna(0)

# %%
kc_1_df.head()
# Out:
#    Field  KC_LESION  KC_ADM  id_1 mouse
# 0      0        0.0     0.0  id_1     1
# 1      1        NaN     0.0  id_1     1
# 2      2        NaN     0.0  id_1     1
# 3      3        NaN     0.0  id_1     1
# 4      4        NaN     0.0  id_1     1

# %%
# concat all the dfs KCG
merged_KCG = pd.concat([kcg_1_df,
                        kcg_2_df,
                        kcg_3_df,
                        kcg_4_df,
                        kcg_5_df,
                        kcg_6_df,
                        kcg_7_df,
                        kcg_8_df,
                        kcg_9_df,
                        kcg_10_df,
                        kcg_11_df,
                        kcg_12_df,
                        kcg_13_df,
                        kcg_14_df,
                        kcg_15_df,
                        kcg_16_df,
                        kcg_17_df
    
], ignore_index=True)

# %%
# concat all the dfs KC
merged_KC = pd.concat([kc_1_df,
                        kc_2_df,
                        kc_3_df,
                        kc_4_df,
                        kc_5_df,
                        kc_6_df,
                        kc_7_df,
                        kc_8_df,
                        kc_9_df,
                        kc_10_df,
                        kc_11_df,
                        kc_12_df
    
], ignore_index=True)

# %%
# Plot KCG mice
#sns.set_style("whitegrid")
cmap = ['gray', 'blue']


kcg = sns.relplot(data=merged_KCG, 
            x='Field', 
            y='mouse',
            hue='KCG_ADM', 
            size='KCG_LESION',
            sizes=(20, 400),
            height=6,
            aspect=2.5,
            palette=cmap
            )
# Change axis titles
kcg.set(title="KCG MICE P40-P60", xlabel='Fields', ylabel='Mouse')

# Save figure
plt.savefig('KCG_P40_P60.pdf', dpi=300)

# %%
# Plot KC
cmap = ['gray', 'blue']


kc = sns.relplot(data=merged_KC, 
            x='Field', 
            y='mouse',
            hue='KC_ADM', 
            size='KC_LESION',
            sizes=(20, 400),
            height=6,
            aspect=2.5,
            palette=cmap
            )
# Change axis titles
kc.set(title="KC MICE P40-P60", xlabel='Fields', ylabel='Mouse')

# Save figure
plt.savefig('KC_P40_P60.pdf', dpi=300)
